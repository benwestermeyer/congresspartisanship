# %% [markdown]
# **Downloading Senate Voting Data**

# %%
import requests # to retrieve data from urls
import shutil # to duplicate csv files

import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning) # suppresses a certificate verification warning

def callme(congress, bill):
    url = "https://www.govtrack.us/congress/votes/96-1979" # we are looking at bills from 2016, the 114th congress
    year = url[-4:] # this will help us title the csv files
    url = url + "/" + congress + bill + "/export/csv" # create the full csv url based on the function call
    print url
    r = requests.get(url, verify=False, stream=True, timeout=10.0)
    if r.status_code != 200: # if page is not found
        print "Failure!"
        exit()
    else:
        r.raw.decode_content = True
        with open("%s%s%s.csv" % (year, congress, bill), 'wb') as f:
            shutil.copyfileobj(r.raw, f) # copy and save the csv
        print "Success"

for i in range(1,505): 
    callme("s", str(i)) # we want to save csvs of the the senate votes 1-163 for the year 2016
# Out:
# https://www.govtrack.us/congress/votes/96-1979/s1/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s2/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s3/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s4/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s5/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s6/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s7/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s8/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s9/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s10/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s11/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s12/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s13/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s14/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s15/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s16/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s17/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s18/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s19/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s20/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s21/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s22/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s23/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s24/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s25/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s26/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s27/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s28/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s29/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s30/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s31/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s32/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s33/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s34/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s35/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s36/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s37/export/csv
# Success
# https://www.govtrack.us/congress/votes/96-1979/s38/export/csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-c052a6e76598> in <module>()
#      21
#      22 for i in range(1,505):
# ---> 23     callme("s", str(i)) # we want to save csvs of the the senate votes 1-163 for the year 2016
#
# <ipython-input-1-c052a6e76598> in callme(congress, bill)
#      10     url = url + "/" + congress + bill + "/export/csv" # create the full csv url based on the function call
#      11     print url
# ---> 12     r = requests.get(url, verify=False, stream=True, timeout=10.0)
#      13     if r.status_code != 200: # if page is not found
#      14         print "Failure!"
#
# D:\Anaconda2.7\lib\site-packages\requests\api.pyc in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# D:\Anaconda2.7\lib\site-packages\requests\api.pyc in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# D:\Anaconda2.7\lib\site-packages\requests\sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# D:\Anaconda2.7\lib\site-packages\requests\sessions.pyc in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# D:\Anaconda2.7\lib\site-packages\requests\adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# D:\Anaconda2.7\lib\site-packages\urllib3\connectionpool.pyc in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# D:\Anaconda2.7\lib\site-packages\urllib3\connectionpool.pyc in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378         try:
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
#
# D:\Anaconda2.7\lib\httplib.pyc in getresponse(self, buffering)
#    1119
#    1120         try:
# -> 1121             response.begin()
#    1122             assert response.will_close != _UNKNOWN
#    1123             self.__state = _CS_IDLE
#
# D:\Anaconda2.7\lib\httplib.pyc in begin(self)
#     436         # read until we get a non-100 response
#     437         while True:
# --> 438             version, status, reason = self._read_status()
#     439             if status != CONTINUE:
#     440                 break
#
# D:\Anaconda2.7\lib\httplib.pyc in _read_status(self)
#     392     def _read_status(self):
#     393         # Initialize with Simple-Response defaults
# --> 394         line = self.fp.readline(_MAXLINE + 1)
#     395         if len(line) > _MAXLINE:
#     396             raise LineTooLong("header line")
#
# D:\Anaconda2.7\lib\socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# D:\Anaconda2.7\lib\site-packages\urllib3\contrib\pyopenssl.pyc in recv(self, *args, **kwargs)
#     268                 raise
#     269         except OpenSSL.SSL.WantReadError:
# --> 270             rd = util.wait_for_read(self.socket, self.socket.gettimeout())
#     271             if not rd:
#     272                 raise timeout('The read operation timed out')
#
# D:\Anaconda2.7\lib\site-packages\urllib3\util\wait.pyc in wait_for_read(socks, timeout)
#      31     or optionally a single socket if passed in. Returns a list of
#      32     sockets that can be read from immediately. """
# ---> 33     return _wait_for_io_events(socks, EVENT_READ, timeout)
#      34
#      35
#
# D:\Anaconda2.7\lib\site-packages\urllib3\util\wait.pyc in _wait_for_io_events(socks, events, timeout)
#      24             selector.register(sock, events)
#      25         return [key[0].fileobj for key in
# ---> 26                 selector.select(timeout) if key[1] & events]
#      27
#      28
#
# D:\Anaconda2.7\lib\site-packages\urllib3\util\selectors.pyc in select(self, timeout)
#     318             ready = []
#     319             r, w, _ = _syscall_wrapper(self._select, True, self._readers,
# --> 320                                        self._writers, timeout)
#     321             r = set(r)
#     322             w = set(w)
#
# D:\Anaconda2.7\lib\site-packages\urllib3\util\selectors.pyc in _syscall_wrapper(func, recalc_timeout, *args, **kwargs)
#      92         while result is _SYSCALL_SENTINEL:
#      93             try:
# ---> 94                 result = func(*args, **kwargs)
#      95             # OSError is thrown by select.select
#      96             # IOError is thrown by select.epoll.poll
#
# D:\Anaconda2.7\lib\site-packages\urllib3\util\selectors.pyc in _select(self, r, w, timeout)
#     308         def _select(self, r, w, timeout=None):
#     309             """ Wrapper for select.select because timeout is a positional arg """
# --> 310             return select.select(r, w, [], timeout)
#     311
#     312         def select(self, timeout=None):
#
# KeyboardInterrupt:

# %% [markdown]
# ** Creating a Senate Network**

# %%
import pandas as pd
import csv
import networkx as nx
import matplotlib.pyplot as plt
import graphviz
import pydot
import pydotplus


G = nx.MultiGraph()
color_map = []

def multigraph_to_weighted_graph(M):
    """Convert a nx.MultiGraph into a weighted nx.Graph."""
    G = nx.Graph()
    for u,v,data in M.edges(data=True):
        w = data['weight'] if 'weight' in data else 1.0
        if G.has_edge(u,v):
            G[u][v]['weight'] += w
        else:
            G.add_edge(u, v, weight=w)
    return G


def addabill(bill):
    

    #renaming columns for easier use
    column_names = ['person', 'state', 'district', 'vote', 'name', 'party'] #renames numerical column labels with actual column labels
    x = pd.read_csv(bill, header=None, skiprows=2, names =column_names) #skips title of document

    #print x
    #print(x['vote'])
    #print(x['person'])
    #print x.iterrows()

    #add senators
    G.add_nodes_from(x['name'])


    #make a list of yes voters and no voters, and non-voters
    yesVoters = []
    noVoters = []
    nonVoters = []
    for index, row in x.iterrows():
        if(row['vote'] == 'Yea'):
            yesVoters.append(row['name'])
            G.add_nodes_from
        elif(row['vote'] == 'Nay'):
            noVoters.append(row['name'])
        elif(row['vote'] == 'Not Voting'):
            nonVoters.append(row['name'])
        #print row['vote'], row['name']

    for i, pol_i in enumerate(yesVoters):
        for j, pol_j in enumerate(yesVoters):
            if i < j:
                G.add_edge(pol_i, pol_j)


    for i, pol_i in enumerate(noVoters):
        for j, pol_j in enumerate(noVoters):
            if i < j:
                G.add_edge(pol_i, pol_j)

                
    for i, pol_i in enumerate(nonVoters):
        for j, pol_j in enumerate(nonVoters):
            if i < j:
                G.add_edge(pol_i, pol_j)

    import sys
    reload(sys)
    sys.setdefaultencoding('utf8')


    #make a list of Republicans, Democrats, and Other
    rep = []
    dem = []
    other = []
    for index, row in x.iterrows():
        if(row['party'] == 'Republican'):
            rep.append(row['name'])
        elif(row['party'] == 'Democrat'):
            dem.append(row['name'])
        else:
            other.append(row['name'])

    #create network of congresspeople colored on their party
    for node in G:
        if node in rep:
            color_map.append('red')
        elif node in dem:
            color_map.append('blue') 
        elif node in other:
            color_map.append('purple')
            
        
for i in range(1, 505):
    addabill("1979s%s.csv" %i)
    
G = multigraph_to_weighted_graph(G)
       

#print G.number_of_edges()
#print G.number_of_nodes()
#print G.nodes

# %% [markdown]
# **Visualization of 2016 Senate Bill Voting Network**

# %%
plt.figure(figsize=(20, 20))
plt.axis('Off')
pos = nx.spring_layout(G, k = .95, iterations=100)
edges, weights = zip(*nx.get_edge_attributes(G,'weight').items())
nx.draw(G,pos=pos, node_color = color_map, edgelist=edges, edge_color=weights, width=[d['weight'] / 50. for _, _, d in G.edges(data=True)], edge_cmap=plt.cm.Greens)
plt.show()

# %% [markdown]
# **Visualization of Senators' Total Number of Edges**

# %%
def sen_total_weights(senator):
    edgetotal = 0
    
    senlinks = G[senator]
    senlinks = dict(senlinks)
    
    for i in range(len(senlinks.items())):
        edgetotal += senlinks.values()[i].values()[0]
        
    return edgetotal



total_weight_dict = {}
for i in list(G.nodes()):
    total_weight_dict[i] = sen_total_weights(i)


keys, values = zip(*sorted(total_weight_dict.items(), key=lambda kv: kv[1]))

anewcolormap = []
rep = []
dem = []
other = []

for i in keys:
    if "[R" in i:
        rep.append(i)
    elif "[D" in i:
        dem.append(i)
    else:
        other.append(i)

#create network of congresspeople colored on their party
for node in keys:
    if node in rep:
        anewcolormap.append('red')
    elif node in dem:
        anewcolormap.append('blue') 
    elif node in other:
        anewcolormap.append('purple')

plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(10, 20))
plt.barh(range(len(values)), values, color=anewcolormap)
#plt.title("Who reaches across the aisle most frequently?", color = "black", fontsize = 15)
plt.xticks(fontsize = 12)
plt.yticks(range(len(values)), keys, fontsize=11)
#plt.yticks(fontsize = 12)
#plt.savefig("hello.png")
plt.ylabel("Senators")
plt.xlabel("Number of Edges")
plt.show()

# %% [markdown]
# **Calculation of Senators' Edges with Senators Outside of their Party**

# %%
def across_edges_total(senator):

    across_edges_total = 0

    sen_links = G[senator]
    sen_links = dict(sen_links)

    for key,val in sen_links.iteritems():
        # for republicans
        if "[R" in senator:
            if "[D" in key:
                across_edges_total += val.values()[0]
            elif "[I" in key:
                across_edges_total += val.values()[0]
                
        # for democrats
        elif "[D" in senator:
            if "[R" in key:
                across_edges_total += val.values()[0]
            elif "[I" in key:
                across_edges_total += val.values()[0]

        # for independents
        elif "[I" in senator:
            if "[R" in key:
                across_edges_total += val.values()[0]
            elif "[D" in key:
                across_edges_total += val.values()[0]
                
    return across_edges_total


across_edges_dict = {}
for i in list(G.nodes()):
    across_edges_dict[i] = across_edges_total(i)
    

'''plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(20, 5))
plt.bar(across_edges_dict.keys(), across_edges_dict.values(), color = color_map)
plt.title("Who reaches across the aisle most?", color = "black", fontsize = 20)
plt.xticks(rotation=90, color = "black", fontsize = 10)
plt.show()'''
# Out:
# 'plt.style.use(\'fivethirtyeight\')\nfig = plt.figure(figsize=(20, 5))\nplt.bar(across_edges_dict.keys(), across_edges_dict.values(), color = color_map)\nplt.title("Who reaches across the aisle most?", color = "black", fontsize = 20)\nplt.xticks(rotation=90, color = "black", fontsize = 10)\nplt.show()'

# %% [markdown]
# **Creating the Reach Metric by Dividing Bipartisan Edges by Total Edges**

# %%
from __future__ import division

# the reach metric is the number of edges a senator has w/ opposite party divided by his number of total edges
reach_metric = dict((k, float(across_edges_dict[k]) / total_weight_dict[k]) for k in across_edges_dict)

adj_reach_metric = {}

for i, j in reach_metric.iteritems():
    if "[R" in i:
        adj_reach_metric[i] = j/58 # to normalize for the fact that there are only 44 democratic senators for republicans to vote with
    elif "[D" in i:
        adj_reach_metric[i] = j/41 # to normalize for the fact that there are 54 republicans for democrats to vote with

# we adjust the reach metrics to penalize democrat scores. they are inflated because there are more republicans in the senate to vote with
# once adjusted, our reach metric is the fraction of a senator's votes which are bipartisan per opposite party politician


keys, values = zip(*sorted(adj_reach_metric.items(), key=lambda kv: kv[1])) # we want to sort the bars from largest to smallest
  
anewcolormap = []
rep = []
dem = []
other = []

for i in keys:
    if "[R" in i:
        rep.append(i)
    elif "[D" in i:
        dem.append(i)
    else:
        other.append(i)

#create network of congresspeople colored on their party
for node in keys:
    if node in rep:
        anewcolormap.append('red')
    elif node in dem:
        anewcolormap.append('blue') 
    elif node in other:
        anewcolormap.append('purple')

plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(10, 20))
plt.barh(range(len(values)), values, color=anewcolormap)
#plt.title("Who reaches across the aisle most frequently?", color = "black", fontsize = 15)
plt.xticks(fontsize = 12)
plt.yticks(range(len(values)), keys, fontsize=11)
#plt.yticks(fontsize = 12)
#plt.savefig("hello.png")
plt.xlabel("'Reach'")
plt.ylabel("Senators")
plt.show()
